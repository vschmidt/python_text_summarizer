# %% [markdown]
# # Modules import

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.probability import FreqDist

from string import punctuation
from collections import defaultdict
from heapq import nlargest

import pandas as pd
import spacy

# %%
#nltk.download() -> For install NLTK corpus
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# # Data import

# %%
path = 'inputs/manifesto.txt'

file_ = open(path, 'r')
text = file_.read()
file_.close()

# %%
text[:50]
# Out:
# 'Um espectro está assombrando o mundo moderno, o es'

# %% [markdown]
# # FreqCount Words Method

# %% [markdown]
# ## Tokenizer

# %%
sents = sent_tokenize(text)
words = word_tokenize(text)

# %%
sents[:2]
# Out:
# ['Um espectro está assombrando o mundo moderno, o espectro da anarquia da criptografia.',
#  'A tecnologia da computação está prestes a fornecer a habilidade de indivíduos e grupos de se comunicar e interagir uns com os outros de maneira totalmente anônima.']

# %%
words[:2]
# Out:
# ['Um', 'espectro']

# %% [markdown]
# ## Stopwords

# %%
stop_words = set(stopwords.words('portuguese') + list(punctuation))
stop_words
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  'a',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'estamos',
#  'estas',
#  'estava',
#  'estavam',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéramos',
#  'estivéssemos',
#  'estou',
#  'está',
#  'estávamos',
#  'estão',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fui',
#  'fôramos',
#  'fôssemos',
#  'haja',
#  'hajam',
#  'hajamos',
#  'havemos',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houveram',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houvermos',
#  'houverá',
#  'houverão',
#  'houveríamos',
#  'houvesse',
#  'houvessem',
#  'houvéramos',
#  'houvéssemos',
#  'há',
#  'hão',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'não',
#  'nós',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'será',
#  'serão',
#  'seríamos',
#  'seu',
#  'seus',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'são',
#  'só',
#  'também',
#  'te',
#  'tem',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'terá',
#  'terão',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéramos',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'tém',
#  'tínhamos',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos',
#  '{',
#  '|',
#  '}',
#  '~',
#  'à',
#  'às',
#  'é',
#  'éramos'}

# %%
words_stopwords_off = [w for w in words
                      if w not in stop_words] #Remove Stopwords

words_stopwords_off
# Out:
# ['Um',
#  'espectro',
#  'assombrando',
#  'mundo',
#  'moderno',
#  'espectro',
#  'anarquia',
#  'criptografia',
#  'A',
#  'tecnologia',
#  'computação',
#  'prestes',
#  'fornecer',
#  'habilidade',
#  'indivíduos',
#  'grupos',
#  'comunicar',
#  'interagir',
#  'uns',
#  'outros',
#  'maneira',
#  'totalmente',
#  'anônima',
#  'Duas',
#  'pessoas',
#  'podem',
#  'trocar',
#  'mensagens',
#  'realizar',
#  'negócios',
#  'negociar',
#  'contratos',
#  'eletrônicos',
#  'nunca',
#  'conhecer',
#  'Nome',
#  'Verdadeiro',
#  'identidade',
#  'legal',
#  'outro',
#  'Interações',
#  'através',
#  'redes',
#  'poderão',
#  'ser',
#  'rastreadas',
#  'através',
#  'extenso',
#  'redirecionamento',
#  'pacotes',
#  'criptografados',
#  'caixas',
#  'prova',
#  'adulteração',
#  'implementam',
#  'protocolos',
#  'criptográficos',
#  'garantia',
#  'quase',
#  'perfeita',
#  'contra',
#  'qualquer',
#  'adulteração',
#  'Reputações',
#  'importância',
#  'central',
#  'importante',
#  'negociações',
#  'classificações',
#  'crédito',
#  'hoje',
#  'Esses',
#  'desenvolvimentos',
#  'alterarão',
#  'completamente',
#  'natureza',
#  'regulamentação',
#  'governamental',
#  'capacidade',
#  'tributar',
#  'controlar',
#  'interações',
#  'econômicas',
#  'capacidade',
#  'manter',
#  'informações',
#  'segredo',
#  'alterarão',
#  'natureza',
#  'confiança',
#  'reputação',
#  'A',
#  'tecnologia',
#  'revolução',
#  'certamente',
#  'revolução',
#  'social',
#  'econômica',
#  'existe',
#  'teoria',
#  'desde',
#  'última',
#  'década',
#  'Os',
#  'métodos',
#  'baseados',
#  'criptografia',
#  'chave',
#  'pública',
#  'sistemas',
#  'prova',
#  'interativa',
#  'conhecimento',
#  'zero',
#  'vários',
#  'protocolos',
#  'software',
#  'interação',
#  'autenticação',
#  'verificação',
#  'O',
#  'foco',
#  'agora',
#  'sido',
#  'conferências',
#  'acadêmicas',
#  'Europa',
#  'EUA',
#  'conferências',
#  'monitoradas',
#  'perto',
#  'Agência',
#  'Nacional',
#  'Segurança',
#  'Mas',
#  'recentemente',
#  'redes',
#  'computadores',
#  'computadores',
#  'pessoais',
#  'alcançaram',
#  'velocidade',
#  'suficiente',
#  'tornar',
#  'ideias',
#  'realizáveis',
#  'prática',
#  'E',
#  'próximos',
#  'dez',
#  'anos',
#  'trarão',
#  'velocidade',
#  'adicional',
#  'suficiente',
#  'tornar',
#  'idéias',
#  'economicamente',
#  'viáveis',
#  'essencialmente',
#  'irrefreáveis',
#  'Redes',
#  'alta',
#  'velocidade',
#  'ISDN',
#  'caixas',
#  'prova',
#  'falsificação',
#  'cartões',
#  'inteligentes',
#  'satélites',
#  'transmissores',
#  'banda',
#  'Ku',
#  'computadores',
#  'pessoais',
#  'multi-MIPS',
#  'chips',
#  'criptografia',
#  'agora',
#  'desenvolvimento',
#  'algumas',
#  'tecnologias',
#  'capacitadoras',
#  'O',
#  'Estado',
#  'tentará',
#  'claro',
#  'desacelerar',
#  'deter',
#  'disseminação',
#  'dessa',
#  'tecnologia',
#  'citando',
#  'preocupações',
#  'segurança',
#  'nacional',
#  'uso',
#  'tecnologia',
#  'traficantes',
#  'drogas',
#  'sonegadores',
#  'impostos',
#  'temores',
#  'desintegração',
#  'social',
#  'Muitas',
#  'dessas',
#  'preocupações',
#  'válidas',
#  'anarquia',
#  'criptografada',
#  'permitirá',
#  'segredos',
#  'nacionais',
#  'livremente',
#  'negociados',
#  'permitirá',
#  'comércio',
#  'materiais',
#  'ilícitos',
#  'roubados',
#  'Um',
#  'mercado',
#  'informatizado',
#  'anônimo',
#  'possibilitará',
#  'mercados',
#  'abomináveis',
#  'assassinatos',
#  'extorsão',
#  'Vários',
#  'elementos',
#  'criminosos',
#  'usuários',
#  'ativos',
#  'CryptoNet',
#  'Mas',
#  'interromperá',
#  'disseminação',
#  'anarquia',
#  'criptográfica',
#  'Assim',
#  'tipografia',
#  'alterou',
#  'reduziu',
#  'poder',
#  'guildas',
#  'medievais',
#  'estrutura',
#  'poder',
#  'social',
#  'métodos',
#  'criptológicos',
#  'alteram',
#  'fundamentalmente',
#  'natureza',
#  'corporações',
#  'interferência',
#  'governo',
#  'transações',
#  'econômicas',
#  'Combinado',
#  'mercados',
#  'informação',
#  'emergentes',
#  'anarquia',
#  'criptográfica',
#  'criará',
#  'mercado',
#  'líquido',
#  'todo',
#  'qualquer',
#  'material',
#  'possa',
#  'ser',
#  'colocado',
#  'palavras',
#  'imagens',
#  'E',
#  'assim',
#  'invenção',
#  'aparentemente',
#  'pequena',
#  'arame',
#  'farpado',
#  'tornou',
#  'possível',
#  'cercamento',
#  'vastas',
#  'fazendas',
#  'campos',
#  'alterando',
#  'sempre',
#  'conceitos',
#  'terra',
#  'direitos',
#  'propriedade',
#  'fronteira',
#  'oeste',
#  'descoberta',
#  'aparentemente',
#  'menor',
#  'ramo',
#  'arcaico',
#  'matemática',
#  'passa',
#  'ser',
#  'cortador',
#  'arame',
#  'desmonta',
#  'arame',
#  'farpado',
#  'torno',
#  'propriedade',
#  'intelectual',
#  'Levanta-te',
#  'tens',
#  'nada',
#  'perder',
#  'senão',
#  'cercas',
#  'arame',
#  'farpado']

# %% [markdown]
# ## FreqDist

# %%
words_freq = FreqDist(words_stopwords_off) # Words count
words_freq
# Out:
# FreqDist({'anarquia': 4, 'tecnologia': 4, 'arame': 4, 'criptografia': 3, 'ser': 3, 'prova': 3, 'natureza': 3, 'social': 3, 'computadores': 3, 'velocidade': 3, ...})

# %% [markdown]
# ## Most important sents

# %%
important_sentences = defaultdict(int)

# %%
for i, sent in enumerate(sents):
    for word in word_tokenize(sent.lower()):
        if word in words_freq:
            important_sentences[i] += words_freq[word]

# %%
important_sentences #Rank of most important sentences
# Out:
# defaultdict(int,
#             {0: 14,
#              1: 17,
#              2: 14,
#              3: 35,
#              4: 7,
#              5: 28,
#              6: 18,
#              7: 22,
#              8: 13,
#              9: 22,
#              10: 17,
#              11: 32,
#              12: 30,
#              13: 21,
#              14: 10,
#              15: 5,
#              16: 9,
#              17: 28,
#              18: 25,
#              19: 55,
#              20: 12})

# %%
sents_qtd = 4 #Quantity of sents in summary 

idx_most_important = nlargest(
                                sents_qtd,
                                important_sentences,
                                important_sentences.get
)

idx_most_important
# Out:
# [19, 3, 11, 12]

# %%
summary_content = ''

for i in sorted(idx_most_important): #Print sentences
    summary_content += sents[i] + '\n\n'

print(summary_content)
# Out:
# Interações através de redes não poderão ser rastreadas, através de extenso redirecionamento de pacotes criptografados e caixas à prova de adulteração que implementam protocolos criptográficos com garantia quase perfeita contra qualquer adulteração.
#
# Redes de alta velocidade, ISDN, caixas à prova de falsificação, cartões inteligentes, satélites, transmissores de banda Ku, computadores pessoais multi-MIPS e chips de criptografia agora em desenvolvimento serão algumas das tecnologias capacitadoras.
#
# O Estado tentará, é claro, desacelerar ou deter a disseminação dessa tecnologia, citando preocupações com a segurança nacional, o uso da tecnologia por traficantes de drogas e sonegadores de impostos e temores de desintegração social.
#
# E assim como uma invenção aparentemente pequena como o arame farpado tornou possível o cercamento de vastas fazendas e campos, alterando para sempre os conceitos de terra e direitos de propriedade na fronteira oeste, também a descoberta aparentemente menor de um ramo arcaico de a matemática passa a ser o cortador de arame que desmonta o arame farpado em torno da propriedade intelectual.

# %%
new_path = 'outputs/word_freq.txt'

file_ = open(new_path, 'w')
file_.writelines(summary_content)
file_.close()

# %% [markdown]
# # Prodution

# %%
#Imports
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.probability import FreqDist

from string import punctuation
from collections import defaultdict
from heapq import nlargest


# Paramns
sents_qtd = 4 #Quantity of sents in summary 
path = 'inputs/manifesto.txt' #Input path
new_path = 'outputs/word_freq.txt' #Output path

# Get file
file_ = open(path, 'r')
text = file_.read()
file_.close()

# NPL
sents = sent_tokenize(text)
words = word_tokenize(text)
stop_words = set(stopwords.words('portuguese') + list(punctuation))
words_stopwords_off = [w for w in words
                      if w not in stop_words] #Remove Stopwords


words_freq = FreqDist(words_stopwords_off) # Words count
important_sentences = defaultdict(int)

for i, sent in enumerate(sents):
    for word in word_tokenize(sent.lower()):
        if word in words_freq:
            important_sentences[i] += words_freq[word] 
            



idx_most_important = nlargest(
                                sents_qtd,
                                important_sentences,
                                important_sentences.get
)

# Make summary
summary_content = ''

for i in sorted(idx_most_important): #Print sentences
    summary_content += sents[i] + '\n\n'

# Export
file_ = open(new_path, 'w')
file_.writelines(summary_content)
file_.close()
